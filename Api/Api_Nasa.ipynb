# %%
#api da Nasa con fotos de Marte
#https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos?api_key=DEMO_KEY&sol=1000
#imprime a primeira foto

import requests
from bs4 import BeautifulSoup


endpoint='https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos?api_key=DEMO_KEY&sol=1000'
response = requests.get(endpoint)
soup = BeautifulSoup(response.content, 'html.parser')
#print(soup.prettify())
Photo = response.json()['photos'][0]['img_src']
print(Photo)


#imprime quen foi o autor

autor = response.json()['photos'][0]['rover']['name']
print("O autor da foto foi o rever: {}".format(autor))



#imprime os datos do rover


nome = response.json()['photos'][0]['rover']['name']
print("A foto foi tomada polo: {}".format(nome))

data_lanzamento = response.json()['photos'][0]['rover']['launch_date']
print("Foi lanzado o espacio o día: {}".format(data_lanzamento))

data_amerizaxe = response.json()['photos'][0]['rover']['landing_date']
print("Chegou a Marte o: {}".format(data_amerizaxe))

estado = response.json()['photos'][0]['rover']['status']
print("O seu estado na actualidade é: {}".format(estado))



#imprime os datos da cámara que tomou a foto


info_autor = []

nome = response.json()['photos'][0]['rover']['name']
print("A foto foi tomada polo: {}".format(nome))

camara = response.json()['photos'][0]['camera']['full_name']
print("coa cámara: {}".format(camara))


data = response.json()['photos'][0]['earth_date']
print("o día: {}".format(data))



#imprime o número total de fotos

album = response.json()['photos']
print("o album de fotos consta de: {} fotos".format(len(album)))



#album con tódalas fotos do rover
#Photo execútase na primeira cela

album = []

for i in range(0,len(Photo)):
    foto = response.json()['photos'][i]['img_src']
    album.append(foto)

print(album)
